# %%
import pandas as pd
import numpy as np
import math
# from sklearn.model_selection import train_test_split
# import naive_bayes as NB
from sklearn.linear_model import LogisticRegression

# df = pd.read_csv('../input/banknote-authentication-uci/BankNoteAuthentication.csv', index_col=False)
# X = df.drop(columns=['class'])
# y = df['class']
# # print(y)
# model = LogisticRegression(solver='liblinear', random_state=0)
# model.fit(X, y)
# # print(np.array([0.3294, -4.4552, 4.5718, -0.9888]).reshape(1, -1))
# print(model.predict_proba(np.array([0.3294, -4.4552, 4.5718, -0.9888]).reshape(1, -1)))

dataframe = pd.read_csv("../input/ecoli-data-set/ecoli.csv", delim_whitespace=True)
